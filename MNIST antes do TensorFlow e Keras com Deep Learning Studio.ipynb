# %% [markdown]
# ## Antes do TensorFlow 2 e Keras
#
# ### Luís Carlos Silva Eiras, abril, 2020
#
#
# No curso *Deep Learning Framework, Capítulo 10, Programa 02, Redes Neurais Profundas*, da **Data Science Academy**, são comparadas as acurácias dos seguintes frameworks - em grau crescente de complexidade - para prever dígitos escritos à mão do dataset MNIST:
#
# •	TensorFlow 2 e Keras (Nível Baixo de Complexidade): 0,9798
#
# •	PyTorch (Nível Médio de Complexidade): 0,9650
#
# •	NumPy (Nível Alto de Complexidade): 0,9925
#
# A pergunta é que acurácia seria conseguida de maneira menos complexa, ou seja, um framework que se colocasse antes do TensorFlow 2 e Keras. A escolha foi o Deep Learning Studio 2.5, com a vantagem que não ser escrita nenhum linha de código, mas mantendo as variáveis dos programas (epochs = 10, loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = 'accuracy' etc.).
#
# **1ª. tentativa**
#
# Foi transportado o modelo do TensorFlow 2  e Keras para o Deep Learning Studio:

# %%
from IPython.display import Image
Image('imagens/modelo1.jpg')

# %% [markdown]
# A acurácia conseguida foi de apenas 0,5577.

# %% [markdown]
# **2ª. tentativa**
#
# Para não deturpar muito o modelo original, foram introduzidos os dropouts: a acurácia aumentou para 0,7795, uma melhoria, mas ainda insuficiente para ser confiável:

# %%
from IPython.display import Image
Image('imagens/modelo2.jpg')

# %% [markdown]
# **3ª. tentativa**
#
# Como a ideia era não usar nenhuma linha de código, foi utilizado sobre o modelo anterior o autoML, recurso de programação automática do Deep Learning Studio. Isso provocou uma grande modificação no modelo original, com introdução do pré-processamento, além do já utilizado no carregamento do MNIST, mas a acurácia soltou para 0,9240:

# %%
from IPython.display import Image
Image('imagens/modelo3.jpg')

# %% [markdown]
# **4ª. tentativa**
#
# Entretanto, essa acurácia é inferior a encontrada no exemplo mais simples e que está dentro no Deep Learning Studio: 0,9848, que é um pouco acima do apurado pelo TensorFlow 2 e Keras:

# %%
from IPython.display import Image
Image('imagens/modelo4.jpg')

# %% [markdown]
# Aqui a comparação entre as 7 acurácias encontradas:
#
# • TensorFlow 2 e Keras: 0,9798
#
# • PyTorch: 0,9650
#
# • NumPy: 0,9925

# %%
from IPython.display import Image
Image('imagens/total.jpg')

# %% [markdown]
# O NumPy com 0,9925 ganhou a corrida.
